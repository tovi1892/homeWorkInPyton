# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp310-cp310-win_amd64.whl (8.1 MB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.23 in c:\python310\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: pyparsing>=3 in c:\python310\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: pillow>=8 in c:\python310\lib\site-packages (from matplotlib) (12.2.0)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib) (24.0)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python310\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 matplotlib-3.10.8
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5, 6]
y = [10, 20, 22, 11, 13, 1]

# %%
plt.plot(x, y)

# %%
categories = ['Category A', 'Category B', 'Category C','Category D']
values = [23, 45, 56,54]

# %%
plt.bar(categories,values)
# Out:
# <BarContainer object of 4 artists>

# %%
grade=[93,96,89,100,100,85]

# %%
hours=[2,3,1,2.5,5,4]
plt.scatter(grade, hours, c=grade,s=hours)

# %%
ages = [22, 45, 30, 35, 50, 41, 28, 33, 55, 65, 29, 42, 48, 31]

plt.hist(ages, bins=[20, 30, 40, 50, 60, 70], edgecolor='black')

plt.title('Age Distribution')
plt.xlabel('Ages')
plt.ylabel('Number of People')
# Out:
# Text(0, 0.5, 'Number of People')

# %%
years = range(2010, 2021)
consumption_oil = [100, 105, 110, 120, 125, 130, 135, 140, 145, 150, 155]
consumption_gas = [80, 82, 85, 88, 90, 95, 100, 105, 110, 115, 120]
consumption_renewable = [20, 25, 30, 35, 40, 45, 50, 60, 70, 80, 90]
fig, axs = plt.subplots(2, 2)  # יוצר מטריצה של גרפים בגודל 2x2
axs[0, 0].plot(consumption_oil, y1, 'tab:blue')
axs[0, 0].set_title('Sin(x)')
axs[0, 1].plot(consumption_oil, y2, 'tab:red')
axs[0, 1].set_title('Cos(x)')
axs[1, 0].scatter(consumption_oil, y1, c='yellow')
axs[1, 0].set_title('Sin(x) Scatter')
axs[1, 1].scatter(x, y2, c='green')
axs[1, 1].set_title('Cos(x) Scatter')

# התאמת הגרפים למראה נקי יותר
for ax in axs.flat:
    ax.label_outer()
